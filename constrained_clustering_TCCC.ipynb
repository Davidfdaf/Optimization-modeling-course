# %%
import pandas as pd
import numpy as np
from pandas_datareader import data, wb
from datetime import datetime
import matplotlib.pyplot as plt
from scipy import stats, integrate
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
import bs4 as bs
import requests
import yfinance as yf
import seaborn as sns

import cvxpy as cp

# %% [markdown]
# ## Get Universe - Current S&P 500 stocks that exhisted in 2002

# %%
import os

if not os.path.exists('SP_Close.pkl'):
    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        tickers.append(ticker)

    tickers = [s.replace('\n', '') for s in tickers]
    start = datetime(2000,1,1)
    end = datetime(2022,1,1)
    data = yf.download(tickers, start=start, end=end)

# %%
if not os.path.exists('SP_Close.pkl'):
    data.index = pd.to_datetime(data.index)
    data = data.sort_index()
    SP_Close = data['Adj Close']
    SP_Close=SP_Close.dropna(axis=0, how='all')
    SP_Close=SP_Close.dropna(axis=1)
else:
    SP_Close = pd.read_pickle('SP_Close.pkl')

pd.set_option('display.max_rows', 20 )
SP_Close
# Out:
#                      A        AAPL         ABC        ABMD         ABT  \
# Date
# 2000-01-03   44.221344    0.854541    3.025873   18.250000    9.347846
# 2000-01-04   40.843311    0.782494    2.819287   17.812500    9.080765
# 2000-01-05   38.309803    0.793945    3.038025   18.000000    9.064073
# 2000-01-06   36.851112    0.725238    3.268915   18.031250    9.381230
# 2000-01-07   39.922039    0.759592    3.694239   17.937500    9.481387
# ...                ...         ...         ...         ...         ...
# 2021-12-27  158.282700  179.836319  131.471329  357.829987  140.403183
# 2021-12-28  158.721420  178.799164  131.929840  357.440002  139.420593
# 2021-12-29  160.187180  178.888916  132.906647  361.839996  140.135193
# 2021-12-30  160.416534  177.712143  133.335266  362.059998  139.946625
# 2021-12-31  159.190079  177.083878  132.458115  359.170013  139.688568
#
#                   ADBE         ADI        ADM         ADP        ADSK  ...  \
# Date                                                                   ...
# 2000-01-03   16.274675   29.523603   6.713816   25.847561    8.052906  ...
# 2000-01-04   14.909398   28.030031   6.643880   25.847561    7.660817  ...
# 2000-01-05   15.204173   28.439224   6.538982   25.599024    7.178244  ...
# 2000-01-06   15.328291   27.661741   6.573946   25.940754    6.740914  ...
# 2000-01-07   16.072985   28.439224   6.678852   26.531029    7.540174  ...
# ...                ...         ...        ...         ...         ...  ...
# 2021-12-27  577.679993  174.617828  65.720932  245.068527  284.299988  ...
# 2021-12-28  569.359985  173.533127  66.576385  244.849625  282.769989  ...
# 2021-12-29  569.289978  174.667587  66.655968  246.779999  282.570007  ...
# 2021-12-30  570.530029  173.931168  66.506760  244.342148  281.709991  ...
# 2021-12-31  567.059998  174.916367  67.232895  245.357101  281.190002  ...
#
#                    WMT        WRB         WST         WY        XEL  \
# Date
# 2000-01-03   44.580296   1.278264    5.451855  12.421493   7.445602
# 2000-01-04   42.912186   1.238933    5.508176  11.954857   7.617051
# 2000-01-05   42.036430   1.219267    5.485648  12.588147   7.910958
# 2000-01-06   42.495152   1.290063    5.429327  13.177001   7.837479
# 2000-01-07   45.706272   1.270398    5.485648  12.743696   7.837479
# ...                ...        ...         ...        ...        ...
# 2021-12-27  139.709854  54.160683  465.444122  38.111694  66.356621
# 2021-12-28  141.714783  54.566757  464.425049  38.303886  67.151077
# 2021-12-29  141.645309  54.932884  467.542084  39.091873  67.488716
# 2021-12-30  142.101868  54.273849  470.888885  39.370552  67.756844
# 2021-12-31  143.610519  54.846344  468.561127  39.572353  67.230515
#
#                   XOM       XRAY         YUM        ZBRA       ZION
# Date
# 2000-01-03  19.671473   6.852272    4.861766   25.027779  38.801506
# 2000-01-04  19.294680   6.852272    4.764044   24.666668  36.922596
# 2000-01-05  20.346552   6.970727    4.788472   25.138889  36.878899
# 2000-01-06  21.398418   6.979842    4.747756   23.777779  37.403233
# 2000-01-07  21.335625   6.961617    4.641887   23.513889  37.490639
# ...               ...        ...         ...         ...        ...
# 2021-12-27  61.211414  55.700321  137.372253  606.330017  62.687782
# 2021-12-28  61.013607  55.779961  137.342392  597.320007  62.787273
# 2021-12-29  60.479530  56.397194  138.019257  601.119995  63.125534
# 2021-12-30  60.123474  56.058052  137.750504  597.539978  62.807171
# 2021-12-31  60.519089  55.649090  138.218338  595.200012  62.837017
#
# [5536 rows x 367 columns]

# %%
if not os.path.exists('SP_Close.pkl'):
    SP_Close.to_pickle('SP_Close.pkl')

# %%
print(SP_Close.dtypes)
print(SP_Close.shape)
# Out:
# A       float64
# AAPL    float64
# ABC     float64
# ABMD    float64
# ABT     float64
#          ...
# XOM     float64
# XRAY    float64
# YUM     float64
# ZBRA    float64
# ZION    float64
# Length: 367, dtype: object
# (5536, 367)

# %%
from sklearn.cluster import AgglomerativeClustering

class constrained_clusterings_new:
    # Initialize with  AAA = constrained_clusterings_new(correlation_matrix)
    # Call with        optimal_num_clusters = AAA.calcthresholds(self,corr_threshold,pct_threshold)
    
    # Optimal number of clusters calculated via:
    # Minimum number of clusters s.t.
    #   (Percent of stocks in clusters with internal correlation less than corr_threshold) is less than pct_threshold
    
    def __init__(self,corr):
        self.corr = corr                     # correlation matrix
        self.sz = corr.shape[0]              # size
        
        self.__precompute()
        
        self.names = pd.DataFrame(corr.columns.values) # stock names
        
    def __precompute(self):
        sz = self.sz
        corr_np = np.array(self.corr)
        
        self.clusters = np.zeros((sz,sz))    # cluster assignments of stocks
        self.numstocks = np.zeros((sz,sz))   # stocks per cluster
        self.internals = np.zeros((sz,sz))   # internal correlations of clusters
        
        for i in range(sz):
            clusters_tmp = AgglomerativeClustering(n_clusters=i+1, affinity='euclidean', linkage='ward').fit_predict(corr_np)
            self.clusters[i,:] = clusters_tmp
            numstocks_tmp = np.zeros(sz)
            internals_tmp = np.zeros(sz)
            for j in range(i+1):
                numstocks_tmp[j] = np.sum(clusters_tmp==j)
                tmpcorr = corr_np[clusters_tmp==j]
                tmpcorr = tmpcorr[:,clusters_tmp==j]
                internals_tmp[j] = np.mean(tmpcorr)
            self.numstocks[i,:] = numstocks_tmp
            self.internals[i,:] = internals_tmp
            
    def calcthresholds(self,corr_threshold,pct_threshold):
        tmp = np.sum((self.internals<corr_threshold)*(self.numstocks/self.sz),axis=1)<pct_threshold
        ret = (np.arange(0,self.sz)+1)[tmp]
#         print("Valid numbers of clusters:")
#         print(ret)
        if ret.shape[0] <= 0:
            return None
        return ret[0]
    
    def get_clusters(self,cluster_number):
        if cluster_number < 1 or cluster_number > self.sz:
            print("Cluster number should be between 1 and",self.sz)
            return None
        ret = pd.DataFrame(self.names)
        ret = ret.set_index(0)
        ret['cluster'] = self.clusters[cluster_number-1,:].astype(int)
        return ret

# %%
def get_clusters(corr, cluster_number = 45, Thresh = None):
    if Thresh == None:
        cluster = AgglomerativeClustering(n_clusters=cluster_number, affinity='euclidean', linkage='ward')
    else:
        cluster = AgglomerativeClustering(n_clusters=None, affinity='euclidean', linkage='ward',distance_threshold=Thresh)
    kclusters = cluster.fit_predict(corr)
    stock_clusters=pd.DataFrame(SP_Close.columns.values)
    stock_clusters=stock_clusters.set_index(0)
    stock_clusters['cluster']=kclusters
    return stock_clusters

# %%
five_year_data=SP_Close[:1265]

# %%
import time

start = time.time()
tmp = constrained_clusterings_new(five_year_data.corr())
print(time.time()-start)
tmp.sz
# Out:
# 11.640833139419556
# 367

# %%
a = tmp.calcthresholds(1,0.5)
print(a)
print(tmp.get_clusters(a))
# Out:
# 248
#       cluster
# 0
# A         246
# AAPL      233
# ABC       137
# ABMD      236
# ABT       146
# ...       ...
# XOM        25
# XRAY        6
# YUM        11
# ZBRA       31
# ZION       65
#
# [367 rows x 1 columns]

# %%
print(get_clusters(five_year_data.corr(), cluster_number = a, Thresh = None))
# Out:
#       cluster
# 0
# A         246
# AAPL      233
# ABC       137
# ABMD      236
# ABT       146
# ...       ...
# XOM        25
# XRAY        6
# YUM        11
# ZBRA       31
# ZION       65
#
# [367 rows x 1 columns]

# %%
a = tmp.calcthresholds(1,0)
print(a)
# Out:
# None

# %%
from sklearn.cluster import AgglomerativeClustering

class constrained_clusterings_new_fast:
    # Initialize with  AAA = constrained_clusterings_new(correlation_matrix)
    # Call with        optimal_num_clusters = AAA.calcthresholds(self,corr_threshold,pct_threshold)
    
    # Optimal number of clusters calculated via:
    # Minimum number of clusters s.t.
    #   (Percent of stocks in clusters with internal correlation less than corr_threshold) is less than pct_threshold
    
    def __init__(self,corr):
        self.corr = corr                     # correlation matrix
        self.sz = corr.shape[0]              # size
        
        self.__precompute()
        
        self.names = pd.DataFrame(corr.columns.values) # stock names
        
    def __precompute(self):
        sz = self.sz
        corr_np = np.array(self.corr)
        
        self.clusters = np.zeros((sz,sz))    # cluster assignments of stocks
        self.numstocks = np.zeros((sz,sz))   # stocks per cluster
        self.internals = np.zeros((sz,sz))   # internal correlations of clusters
        
        for i in range(sz):
            clusters_tmp = AgglomerativeClustering(n_clusters=i+1, affinity='euclidean', linkage='ward').fit_predict(corr_np)
            self.clusters[i,:] = clusters_tmp
            numstocks_tmp = np.zeros(sz)
            internals_tmp = np.zeros(sz)
            for j in range(i+1):
                numstocks_tmp[j] = np.sum(clusters_tmp==j)
                tmpcorr = corr_np[clusters_tmp==j]
                tmpcorr = tmpcorr[:,clusters_tmp==j]
                internals_tmp[j] = np.mean(tmpcorr)
            self.numstocks[i,:] = numstocks_tmp
            self.internals[i,:] = internals_tmp
            
    def calcthresholds(self,corr_threshold,pct_threshold):
        tmp = np.sum((self.internals<corr_threshold)*(self.numstocks/self.sz),axis=1)<pct_threshold
        ret = (np.arange(0,self.sz)+1)[tmp]
#         print("Valid numbers of clusters:")
#         print(ret)
        if ret.shape[0] <= 0:
            return None
        return ret[0]
    
    def get_clusters(self,cluster_number):
        if cluster_number < 1 or cluster_number > self.sz:
            print("Cluster number should be between 1 and",self.sz)
            return None
        ret = pd.DataFrame(self.names)
        ret = ret.set_index(0)
        ret['cluster'] = self.clusters[cluster_number-1,:].astype(int)
        return ret

# %%
from sklearn.cluster import AgglomerativeClustering
#rule is to select number of clusters clusters such that at most stock_pct_thresh of stocks are in clusters 
#with an internal corr of corr_thresh

def constrained_clusters(corr, corr_threshold = .7, pct_threshold = .1,verbose=False, min_clusters = None):
    sz = corr.shape[0]
    corr_np = np.array(corr)
    names = pd.DataFrame(corr.columns.values) # stock names

    clusters = np.zeros((sz,sz))    # cluster assignments of stocks
    numstocks = np.zeros((sz,sz))   # stocks per cluster
    internals = np.zeros((sz,sz))   # internal correlations of clusters

    cluster_number = None
    
    for i in range(sz):
        clusters_tmp = AgglomerativeClustering(n_clusters=i+1, affinity='euclidean', linkage='ward').fit_predict(corr_np)
        clusters[i,:] = clusters_tmp
        numstocks_tmp = np.zeros(sz)
        internals_tmp = np.zeros(sz)
        for j in range(i+1):
            numstocks_tmp[j] = np.sum(clusters_tmp==j)
            tmpcorr = corr_np[clusters_tmp==j]
            tmpcorr = tmpcorr[:,clusters_tmp==j]
            internals_tmp[j] = np.mean(tmpcorr)
        numstocks[i,:] = numstocks_tmp
        internals[i,:] = internals_tmp
        
        tmp = np.sum((internals_tmp<corr_threshold)*(numstocks_tmp/sz))<pct_threshold
        if tmp:
            cluster_number = (np.arange(0,sz)+1)[i]
            break
            
    if not cluster_number:
        # Unable to generate clusters with given corr_, pct_ thresholds
        return None
    ret = pd.DataFrame(names)
    ret = ret.set_index(0)
    ret['cluster'] = clusters_tmp.astype(int)
    return ret

# %%
start = time.time()
print(constrained_clusters(five_year_data.corr(),1,0.5))
print(time.time()-start)
# Out:
#       cluster
# 0
# A         246
# AAPL      233
# ABC       137
# ABMD      236
# ABT       146
# ...       ...
# XOM        25
# XRAY        6
# YUM        11
# ZBRA       31
# ZION       65
#
# [367 rows x 1 columns]
# 7.312881231307983

# %%
SP_Close.index
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14',
#                ...
#                '2021-12-17', '2021-12-20', '2021-12-21', '2021-12-22',
#                '2021-12-23', '2021-12-27', '2021-12-28', '2021-12-29',
#                '2021-12-30', '2021-12-31'],
#               dtype='datetime64[ns]', name='Date', length=5536, freq=None)

# %%
start = '2000-1-1'
end = '2001-1-01'
SP_Close.loc[(SP_Close.index >= start) & (SP_Close.index < end)]
# Out:
#                     A      AAPL        ABC      ABMD        ABT       ADBE  \
# Date
# 2000-01-03  44.221344  0.854541   3.025873  18.25000   9.347846  16.274675
# 2000-01-04  40.843311  0.782494   2.819287  17.81250   9.080765  14.909398
# 2000-01-05  38.309803  0.793945   3.038025  18.00000   9.064073  15.204173
# 2000-01-06  36.851112  0.725238   3.268915  18.03125   9.381230  15.328291
# 2000-01-07  39.922039  0.759592   3.694239  17.93750   9.481387  16.072985
# ...               ...       ...        ...       ...        ...        ...
# 2000-12-22  33.588261  0.229022   9.709534  27.81250  12.885592  32.631466
# 2000-12-26  32.858906  0.224252   9.843204  25.00000  13.106584  32.755657
# 2000-12-27  34.355988  0.226160  10.074092  25.87500  13.208581  32.538315
# 2000-12-28  33.972118  0.226160  10.232070  25.25000  13.191578  30.613342
# 2000-12-29  33.626640  0.227114   9.818891  24.25000  13.174580  28.905701
#
#                   ADI       ADM        ADP      ADSK  ...        WMT  \
# Date                                                  ...
# 2000-01-03  29.523603  6.713816  25.847561  8.052906  ...  44.580296
# 2000-01-04  28.030031  6.643880  25.847561  7.660817  ...  42.912186
# 2000-01-05  28.439224  6.538982  25.599024  7.178244  ...  42.036430
# 2000-01-06  27.661741  6.573946  25.940754  6.740914  ...  42.495152
# 2000-01-07  28.439224  6.678852  26.531029  7.540174  ...  45.706272
# ...               ...       ...        ...       ...  ...        ...
# 2000-12-22  32.244774  8.267658  29.768843  5.857269  ...  35.195786
# 2000-12-26  33.799721  8.379886  30.613144  5.804090  ...  33.938782
# 2000-12-27  36.377659  8.566941  31.426144  6.016805  ...  35.237690
# 2000-12-28  35.354679  8.753987  31.707581  6.442235  ...  35.489079
# 2000-12-29  33.513283  8.978458  31.676306  6.548593  ...  35.614784
#
#                  WRB       WST         WY        XEL        XOM       XRAY  \
# Date
# 2000-01-03  1.278264  5.451855  12.421493   7.445602  19.671473   6.852272
# 2000-01-04  1.238933  5.508176  11.954857   7.617051  19.294680   6.852272
# 2000-01-05  1.219267  5.485648  12.588147   7.910958  20.346552   6.970727
# 2000-01-06  1.290063  5.429327  13.177001   7.837479  21.398418   6.979842
# 2000-01-07  1.270398  5.485648  12.743696   7.837479  21.335625   6.961617
# ...              ...       ...        ...        ...        ...        ...
# 2000-12-22  2.950535  4.543566   9.516582  11.807409  22.276266  11.220172
# 2000-12-26  3.038970  4.566747   9.344599  12.244718  22.725313  11.222086
# 2000-12-27  3.030930  4.531973   9.413395  12.244718  22.516842  11.901651
# 2000-12-28  3.038970  4.636291   9.539515  12.140517  22.292311  12.526125
# 2000-12-29  3.034950  4.555155   9.310206  12.114458  22.308348  11.497583
#
#                  YUM       ZBRA       ZION
# Date
# 2000-01-03  4.861766  25.027779  38.801506
# 2000-01-04  4.764044  24.666668  36.922596
# 2000-01-05  4.788472  25.138889  36.878899
# 2000-01-06  4.747756  23.777779  37.403233
# 2000-01-07  4.641887  23.513889  37.490639
# ...              ...        ...        ...
# 2000-12-22  4.161412  17.666668  44.056164
# 2000-12-26  4.128838  17.194445  43.877808
# 2000-12-27  4.210274  17.777779  43.966991
# 2000-12-28  4.356860  19.527779  44.279129
# 2000-12-29  4.299853  18.131945  44.546684
#
# [252 rows x 367 columns]

# %%
for i in range(1,5+1):
    count = 0
    for j in range(2000+i,2021+1):
        for k in range(1,12+1):
            count += 1
    print(count)
# Out:
# 252
# 240
# 228
# 216
# 204

# %%
from sklearn.cluster import AgglomerativeClustering

class constrained_clusterings_precomputed:
    # Initialize with  AAA = constrained_clusterings_new(correlation_matrix)
    # Call with        optimal_num_clusters = AAA.calcthresholds(self,corr_threshold,pct_threshold)
    
    # Optimal number of clusters calculated via:
    # Minimum number of clusters s.t.
    #   (Percent of stocks in clusters with internal correlation less than corr_threshold) is less than pct_threshold
    
    def __init__(self,lookback):
        llist = [1,2,3,4,5]
        if (int(lookback) != lookback) or (int(lookback) not in llist):
            raise ValueError("Only lookback periods of",llist,"supported")
            
        self.df = pd.read_pickle(str(int(lookback))+'.pkl')
        self.names_df = pd.read_pickle('names.pkl')
        
#         corr_threshold = 0.7
#         pct_threshold = 0.1
#         date = datetime.strptime('3-31-2030','%m-%d-%Y')
        
            
    def calcthresholds(self,corr_threshold,pct_threshold,date):
        if date < min(self.df.index):
            raise ValueError("Date must be >=",min(self.df.index))
        if date > max(self.df.index):
            print("WARNING: USING",max(self.df.index),"FOR INPUT DATE",date)
        inddate = max(self.df.index[self.df.index <= date])
        print(inddate)
#         print(self.df.loc[inddate])
        
        clusters = self.df.loc[inddate]['Clusters']
        numstocks = self.df.loc[inddate]['Numstocks']
        internals = self.df.loc[inddate]['Corrs']
        sz = clusters.shape[0]
        
        tmp = np.sum((internals<corr_threshold)*(numstocks/sz),axis=1)<pct_threshold
        ret = (np.arange(0,sz)+1)[tmp]
        if ret.shape[0] <= 0:
            return None
        OPTIMAL_NUMBER_OF_CLUSTERS = ret[0]
        
        ret_df = self.names_df
        ret_df = ret_df.set_index(0)
        ret_df['cluster'] = clusters[OPTIMAL_NUMBER_OF_CLUSTERS-1,:].astype(int)
        
        print(OPTIMAL_NUMBER_OF_CLUSTERS)
#         print(ret_df)
        return ret_df

# %%
look1 = constrained_clusterings_precomputed(1)
look2 = constrained_clusterings_precomputed(2)
look3 = constrained_clusterings_precomputed(3)
look4 = constrained_clusterings_precomputed(4)
look5 = constrained_clusterings_precomputed(5)

# %%
corr_threshold = 0.7
pct_threshold = 0.1
date = datetime.strptime('3-31-2010','%m-%d-%Y')

look1.calcthresholds(corr_threshold,pct_threshold,date)
look2.calcthresholds(corr_threshold,pct_threshold,date)
look3.calcthresholds(corr_threshold,pct_threshold,date)
look4.calcthresholds(corr_threshold,pct_threshold,date)
look5.calcthresholds(corr_threshold,pct_threshold,date)
# Out:
# 2010-03-01 00:00:00
# 1
# 2010-03-01 00:00:00
# 9
# 2010-03-01 00:00:00
# 21
# 2010-03-01 00:00:00
# 17
# 2010-03-01 00:00:00
# 7
#       cluster
# 0
# A           1
# AAPL        3
# ABC         2
# ABMD        2
# ABT         3
# ...       ...
# XOM         5
# XRAY        5
# YUM         3
# ZBRA        0
# ZION        0
#
# [367 rows x 1 columns]

# %%
def get_clusters_precomputed(lookback,corr_threshold,pct_threshold,date):
    llist = [1,2,3,4,5]
    if (int(lookback) != lookback) or (int(lookback) not in llist):
        raise ValueError("Only lookback periods of",llist,"supported")
        
    # Apparently pattern matching wasn't implemented until Python 3.10
    if lookback == 1:
        return look1.calcthresholds(corr_threshold,pct_threshold,date)
    elif lookback == 2:
        return look2.calcthresholds(corr_threshold,pct_threshold,date)
    elif lookback == 3:
        return look3.calcthresholds(corr_threshold,pct_threshold,date)
    elif lookback == 4:
        return look4.calcthresholds(corr_threshold,pct_threshold,date)
    elif lookback == 5:
        return look5.calcthresholds(corr_threshold,pct_threshold,date)
    else:
        raise ValueError("Something went wrong")

# %%
#     match lookback:
#         case 1:
#             return look1.calcthresholds(corr_threshold,pct_threshold,date)
#         case 2:
#             return look2.calcthresholds(corr_threshold,pct_threshold,date)
#         case 3:
#             return look3.calcthresholds(corr_threshold,pct_threshold,date)
#         case 4:
#             return look4.calcthresholds(corr_threshold,pct_threshold,date)
#         case 5:
#             return look5.calcthresholds(corr_threshold,pct_threshold,date)
#         case _:
#             raise ValueError("Something went wrong")

# %%
corr_threshold = 0.7
pct_threshold = 0.1
date = datetime.strptime('3-31-2010','%m-%d-%Y')

get_clusters_precomputed(1,corr_threshold,pct_threshold,date)
get_clusters_precomputed(2,corr_threshold,pct_threshold,date)
get_clusters_precomputed(3,corr_threshold,pct_threshold,date)
get_clusters_precomputed(4,corr_threshold,pct_threshold,date)
get_clusters_precomputed(5,corr_threshold,pct_threshold,date)
# Out:
# 2010-03-01 00:00:00
# 1
# 2010-03-01 00:00:00
# 9
# 2010-03-01 00:00:00
# 21
# 2010-03-01 00:00:00
# 17
# 2010-03-01 00:00:00
# 7
#       cluster
# 0
# A           1
# AAPL        3
# ABC         2
# ABMD        2
# ABT         3
# ...       ...
# XOM         5
# XRAY        5
# YUM         3
# ZBRA        0
# ZION        0
#
# [367 rows x 1 columns]

# %%
for i in range(3,5+1):
    starttime = time.time()
    # lookback years
    ilist = []
    alist = []
    blist = []
    clist = []
    for j in range(2000+i,2021+1):
        # year
        for k in range(1,12+1):
            # month
            start = str(j-i) + '-' + str(k) + '-01'
            end = str(j) + '-' + str(k) + '-01'
            print(end)
#             print(SP_Close.loc[(SP_Close.index >= start) & (SP_Close.index < end)])
            corr = SP_Close.loc[(SP_Close.index >= start) & (SP_Close.index < end)].corr()
            tmp = constrained_clusterings_new(corr)
            ilist.append(end)
            alist.append(tmp.clusters.astype(int))
            blist.append(tmp.numstocks.astype(int))
            clist.append(tmp.internals)
    df = pd.DataFrame(list(zip(ilist,alist,blist,clist)),columns =['Date', 'Clusters', 'Numstocks', 'Corrs'])
    df = df.set_index('Date')
    df.index = pd.to_datetime(df.index)
#     df.to_pickle(str(i)+'.pkl')
    print(time.time()-starttime)
# Out:
# 2003-1-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19380/2274365692.py in <module>
#      15 #             print(SP_Close.loc[(SP_Close.index >= start) & (SP_Close.index < end)])
#      16             corr = SP_Close.loc[(SP_Close.index >= start) & (SP_Close.index < end)].corr()
# ---> 17             tmp = constrained_clusterings_new(corr)
#      18             ilist.append(end)
#      19             alist.append(tmp.clusters.astype(int))
#
# ~\AppData\Local\Temp/ipykernel_19380/2634130764.py in __init__(self, corr)
#      13         self.sz = corr.shape[0]              # size
#      14
# ---> 15         self.__precompute()
#      16
#      17         self.names = pd.DataFrame(corr.columns.values) # stock names
#
# ~\AppData\Local\Temp/ipykernel_19380/2634130764.py in __precompute(self)
#      32             for j in range(i+1):
#      33                 numstocks_tmp[j] = np.sum(clusters_tmp==j)
# ---> 34                 tmpcorr = corr_np[clusters_tmp==j]
#      35                 tmpcorr = tmpcorr[:,clusters_tmp==j]
#      36                 internals_tmp[j] = np.mean(tmpcorr)
#
# KeyboardInterrupt:

# %%
df
